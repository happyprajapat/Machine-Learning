# %% [markdown]
# Write CSV File

# %%
import pandas as pd

# %%
dis = {"A":(1,2,3,4,5),"B":(6,7,8,9,0),"C":(11,22,33,44,55)}

d =pd.DataFrame(dis)

d.to_csv("Test_new1(With no index).csv",index=False,header=["First","Second","Third"])

# %% [markdown]
# Read CSV

# %%
csv_1 = pd.read_csv("D:\Python\\Pandas\\machine-readable-business-employment-data-mar-2023-quarter.csv")

csv_1
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS   UNITS  \
# 0          BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number
# 1          BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number
# 2          BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number
# 3          BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number
# 4          BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number
# ...                ...      ...         ...        ...    ...     ...
# 21410    BDCQ.SEE3999A  2017.06         NaN          Y      C  Number
# 21411    BDCQ.SEE3999A  2017.09         NaN          Y      C  Number
# 21412    BDCQ.SEE3999A  2017.12         NaN          Y      C  Number
# 21413    BDCQ.SEE3999A  2018.03         NaN          Y      C  Number
# 21414    BDCQ.SEE3999A  2018.06         NaN          Y      C  Number
#
#        Magnitude                         Subject  \
# 0              0  Business Data Collection - BDC
# ...

# %%
csv_2 = pd.read_csv("D:\Python\\Pandas\\machine-readable-business-employment-data-mar-2023-quarter.csv",nrows=3)

csv_2
# Out:
#   Series_reference   Period  Data_value  Suppressed STATUS   UNITS  Magnitude  \
# 0      BDCQ.SEA1AA  2011.06       80078         NaN      F  Number          0
# 1      BDCQ.SEA1AA  2011.09       78324         NaN      F  Number          0
# 2      BDCQ.SEA1AA  2011.12       85850         NaN      F  Number          0
#
#                           Subject                            Group  \
# 0  Business Data Collection - BDC  Industry by employment variable
# 1  Business Data Collection - BDC  Industry by employment variable
# 2  Business Data Collection - BDC  Industry by employment variable
#
#   Series_title_1                     Series_title_2 Series_title_3  \
# 0    Filled jobs  Agriculture, Forestry and Fishing         Actual
# 1    Filled jobs  Agriculture, Forestry and Fishing         Actual
# 2    Filled jobs  Agriculture, Forestry and Fishing         Actual
#
#    Series_title_4  Series_title_5
# 0             NaN             NaN
# 1             NaN             NaN
# ...

# %%
csv_3 = pd.read_csv("D:\Python\\Pandas\\machine-readable-business-employment-data-mar-2023-quarter.csv",usecols=["Period","STATUS"])

csv_3
# Out:
#         Period STATUS
# 0      2011.06      F
# 1      2011.09      F
# 2      2011.12      F
# 3      2012.03      F
# 4      2012.06      F
# ...        ...    ...
# 21410  2017.06      C
# 21411  2017.09      C
# 21412  2017.12      C
# 21413  2018.03      C
# 21414  2018.06      C
#
# [21415 rows x 2 columns]

# %%
csv_4 = pd.read_csv("D:\Python\\Pandas\\machine-readable-business-employment-data-mar-2023-quarter.csv",skiprows=[1])

csv_4
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS   UNITS  \
# 0          BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number
# 1          BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number
# 2          BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number
# 3          BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number
# 4          BDCQ.SEA1AA  2012.09     79261.0        NaN      F  Number
# ...                ...      ...         ...        ...    ...     ...
# 21409    BDCQ.SEE3999A  2017.06         NaN          Y      C  Number
# 21410    BDCQ.SEE3999A  2017.09         NaN          Y      C  Number
# 21411    BDCQ.SEE3999A  2017.12         NaN          Y      C  Number
# 21412    BDCQ.SEE3999A  2018.03         NaN          Y      C  Number
# 21413    BDCQ.SEE3999A  2018.06         NaN          Y      C  Number
#
#        Magnitude                         Subject  \
# 0              0  Business Data Collection - BDC
# ...

# %%
csv_5= pd.read_csv("D:\Python\\Pandas\\machine-readable-business-employment-data-mar-2023-quarter.csv",index_col=["Period"])

csv_5
# Out:
#         Series_reference  Data_value Suppressed STATUS   UNITS  Magnitude  \
# Period
# 2011.06      BDCQ.SEA1AA     80078.0        NaN      F  Number          0
# 2011.09      BDCQ.SEA1AA     78324.0        NaN      F  Number          0
# 2011.12      BDCQ.SEA1AA     85850.0        NaN      F  Number          0
# 2012.03      BDCQ.SEA1AA     90743.0        NaN      F  Number          0
# 2012.06      BDCQ.SEA1AA     81780.0        NaN      F  Number          0
# ...                  ...         ...        ...    ...     ...        ...
# 2017.06    BDCQ.SEE3999A         NaN          Y      C  Number          0
# 2017.09    BDCQ.SEE3999A         NaN          Y      C  Number          0
# 2017.12    BDCQ.SEE3999A         NaN          Y      C  Number          0
# 2018.03    BDCQ.SEE3999A         NaN          Y      C  Number          0
# 2018.06    BDCQ.SEE3999A         NaN          Y      C  Number          0
#
#                                 Subject  \
# Period
# ...

# %%
csv_5= pd.read_csv("D:\Python\\Pandas\\machine-readable-business-employment-data-mar-2023-quarter.csv",header = 2)

csv_5
# Out:
#          BDCQ.SEA1AA  2011.09    78324 Unnamed: 3  F  Number  0  \
# 0        BDCQ.SEA1AA  2011.12  85850.0        NaN  F  Number  0
# 1        BDCQ.SEA1AA  2012.03  90743.0        NaN  F  Number  0
# 2        BDCQ.SEA1AA  2012.06  81780.0        NaN  F  Number  0
# 3        BDCQ.SEA1AA  2012.09  79261.0        NaN  F  Number  0
# 4        BDCQ.SEA1AA  2012.12  87793.0        NaN  F  Number  0
# ...              ...      ...      ...        ... ..     ... ..
# 21408  BDCQ.SEE3999A  2017.06      NaN          Y  C  Number  0
# 21409  BDCQ.SEE3999A  2017.09      NaN          Y  C  Number  0
# 21410  BDCQ.SEE3999A  2017.12      NaN          Y  C  Number  0
# 21411  BDCQ.SEE3999A  2018.03      NaN          Y  C  Number  0
# 21412  BDCQ.SEE3999A  2018.06      NaN          Y  C  Number  0
#
#        Business Data Collection - BDC  \
# 0      Business Data Collection - BDC
# 1      Business Data Collection - BDC
# 2      Business Data Collection - BDC
# 3      Business Data Collection - BDC
# ...

# %%
csv_6= pd.read_csv("D:\Python\\Pandas\\machine-readable-business-employment-data-mar-2023-quarter.csv",names=["Col"])

csv_6
# Out:
#                                                                                                                                                                                                                                                                        Col
# Series_reference Period  Data_value Suppressed STATUS UNITS  Magnitude Subject                        Group                                        Series_title_1                         Series_title_2                     Series_title_3 Series_title_4  Series_title_5
# BDCQ.SEA1AA      2011.06 80078      NaN        F      Number 0         Business Data Collection - BDC Industry by employment variable              Filled jobs                            Agriculture, Forestry and Fishing  Actual         NaN                        NaN
# ...

# %%
csv_7= pd.read_csv("D:\Python\\Pandas\\machine-readable-business-employment-data-mar-2023-quarter.csv",header = None)

csv_7
# Out:
#                      0        1           2           3       4       5   \
# 0      Series_reference   Period  Data_value  Suppressed  STATUS   UNITS
# 1           BDCQ.SEA1AA  2011.06       80078         NaN       F  Number
# 2           BDCQ.SEA1AA  2011.09       78324         NaN       F  Number
# 3           BDCQ.SEA1AA  2011.12       85850         NaN       F  Number
# 4           BDCQ.SEA1AA  2012.03       90743         NaN       F  Number
# ...                 ...      ...         ...         ...     ...     ...
# 21411     BDCQ.SEE3999A  2017.06         NaN           Y       C  Number
# 21412     BDCQ.SEE3999A  2017.09         NaN           Y       C  Number
# 21413     BDCQ.SEE3999A  2017.12         NaN           Y       C  Number
# 21414     BDCQ.SEE3999A  2018.03         NaN           Y       C  Number
# 21415     BDCQ.SEE3999A  2018.06         NaN           Y       C  Number
#
#               6                               7   \
# ...
